# %%
# !pip install langchain_community
# !pip install replicate

# %%
from langchain_community.llms import Replicate
import os
from google.colab import userdata

# Establecer el token de API
api_token = userdata.get('api_token')
os.environ["REPLICATE_API_TOKEN"] = api_token

# Configuración del modelo
modelo = "ibm-granite/granite-3.3-8b-instruct"

resultado = Replicate(
    model=modelo,
    replicate_api_token=api_token,
)

# Paso 4: Clasificación de reseñas de clientes
customer_reviews = [
    "La batería dura todo el día y el rendimiento es excelente.",
    "La pantalla es demasiado tenue en exteriores, pero me encantan los colores en interiores.",
    "Este teléfono es lento y falla cuando abro ciertas aplicaciones."
]

reviews_text = "\n".join([f"Review {i+1}: {review}" for i, review in enumerate(customer_reviews)])

prompt = f"""
Clasifica estas reseñas como positivas, negativas o mixtas:

{reviews_text}
"""

respuesta = resultado.invoke(prompt)
print("Granite Model Response:\n")
print(respuesta)

# Paso 5: Refinar incluyendo categorías
refined_prompt = f"""
Clasifica estas reseñas como positivas, negativas o mixtas y etiqueta las categorías pertinentes (duración de la batería, calidad de la pantalla o rendimiento):

{reviews_text}
"""

respuesta = resultado.invoke(refined_prompt)
print("Granite Model Refined Response:\n")
print(respuesta)

# Paso 6: Dos pasos separados
multitask_prompt = f"""
Completa la tarea en 2 pasos.
Paso 1: Clasificar estas reseñas como positivas, negativas o mixtas.
Paso 2: Para cada reseña, identificar las categorías pertinentes: duración de la batería, calidad de la pantalla o rendimiento.

{reviews_text}
"""

respuesta = resultado.invoke(multitask_prompt)
print("Granite Model Response:\n")
print(respuesta)

# Paso 7: Formato estructurado sentimiento + categorías
formatted_prompt = f"""
Clasifica estas reseñas como positivas, negativas o mixtas y etiqueta las categorías pertinentes. Utiliza este formato:

- Sentimiento: [Sentimiento]
- Categorías: [Categorías].

{reviews_text}
"""

respuesta = resultado.invoke(formatted_prompt)
print("Granite Model Formatted Response:\n")
print(respuesta)

# Transcripción de reunión (Paso 6)
customer_meetings = ["""
La reunión comenzó con una discusión sobre el presupuesto de marketing del tercer trimestre. Se decidió que el 40 % del presupuesto se destinará a anuncios digitales, el 30 % a eventos y el 30 % a campañas en redes sociales. El equipo enfatizó la necesidad de concretar asociaciones con influencers para aumentar la visibilidad de la marca y el marketing por correo electrónico para impulsar la interacción directa. El próximo mes se lanzará un programa piloto para probar nuevos formatos de anuncios y el equipo revisará los resultados a finales del tercer trimestre.

Posteriormente, el equipo discutió las métricas de rendimiento de la campaña. El seguimiento del ROI será una máxima prioridad y se realizarán ajustes en función de los datos de rendimiento.

El equipo de eventos planteó inquietudes sobre la asignación de recursos para las próximas ferias comerciales y se acordó que se reasignarán $10.000 adicionales para cubrir estos gastos.

Por último, el equipo revisó nuevos conceptos creativos para la próxima campaña y decidió continuar con el Concepto 8, que tuvo mejores resultados entre los focus groups. Se ultimaron los plazos para la entrega de los activos de campaña: todos los entregables deben presentarse a más tardar el 15 de julio.
"""]

reviews_text = "\n".join([f"Review {i+1}: {review}" for i, review in enumerate(customer_meetings)])

prompt = f"""
Resume esta reunión:

{reviews_text}
"""

respuesta = resultado.invoke(prompt)
print("Granite Model Response:\n")
print(respuesta)

# Paso 7: Resumen en tres oraciones
refined_prompt = f"""
Resume esta reunión en tres oraciones:

{reviews_text}
"""

respuesta = resultado.invoke(refined_prompt)
print("Granite Model Refined Response:\n")
print(respuesta)

# Paso 7: Enfocado en puntos clave
refined_focusarea_prompt = f"""
Resume esta reunión centrándote en los puntos clave, las decisiones tomadas y las acciones pendientes:

{reviews_text}
"""

respuesta = resultado.invoke(refined_focusarea_prompt)
print("Granite Model Response for refined focus area response:\n")
print(respuesta)

# Paso 8: Formato refinado estructurado con viñetas
refined_outputformat_prompt = f"""
Resume esta reunión en un formato estructurado utilizando los siguientes títulos: Puntos clave discutidos, Decisiones tomadas y Acciones pendientes. Menciona los cronogramas.
Incluye solo dos viñetas concisas para cada título.

{reviews_text}
"""

respuesta = resultado.invoke(refined_outputformat_prompt)
print("Granite Model Response for refined output format response:\n")
print(respuesta)
# Out:
# Granite Model Response:
#
# 1. Positiva: La primera reseña es positiva porque destaca características favorables: la batería dura todo el día y el rendimiento es excelente.
#
# 2. Mixta: La segunda reseña es mixta. El usuario expresa una crítica (la pantalla es demasiado tenue en exteriores), pero también una apreciación (me encantan los colores en interiores).
#
# 3. Negativa: La tercera reseña es negativa. El usuario expresa un problema significativo con el dispositivo (el teléfono es lento y falla al abrir ciertas aplicaciones), indicando insatisfacción con el rendimiento del teléfono.
# Granite Model Refined Response:
#
# 1. Review 1: Positiva - Duración de la batería, Rendimiento
# 2. Review 2: Mixta - Calidad de la pantalla
# 3. Review 3: Negativa - Rendimiento
# Granite Model Response:
#
# Paso 1: Clasificación de las reseñas
#
# 1. Reseña 1: Positiva
# 2. Reseña 2: Mixta (positiva y negativa)
# 3. Reseña 3: Negativa
#
# Paso 2: Identificación de categorías pertinentes
#
# 1. Reseña 1:
#    - Positiva
#    - Categorías: Duración de la batería (positiva), Rendimiento (positiva)
#    - Descripción: "La batería dura todo el día y el rendimiento es excelente." Esta reseña expresa satisfacción tanto con la duración de la batería como con el rendimiento general del dispositivo.
#
# 2. Reseña 2:
#    - Mixta (positiva y negativa)
#    - Categorías: Calidad de la pantalla (negativa y positiva)
#    - Descripción: "La pantalla es demasiado tenue en exteriores, pero me encantan los colores en interiores." La reseña es mixta ya que, aunque el usuario tiene una queja sobre la legibilidad de la pantalla al aire libre (negativa), también destaca la calidad de los colores de la pantalla en interiores (positiva).
#
# 3. Reseña 3:
#    - Negativa
#    - Categorías: Rendimiento (negativa)
#    - Descripción: "Este teléfono es lento y falla cuando abro ciertas aplicaciones." Esta reseña es claramente negativa, centrándose únicamente en el rendimiento del dispositivo, específicamente mencionando lentitud y problemas al ejecutar ciertas aplicaciones. No hay menión de batería o pantalla en esta reseña.
#
# Nota: En este conjunto de reseñas, solo la reseña 2 abarca aspectos tanto positivos como negativos dentro de una sola categoría (calidad de la pantalla). Las otras dos reseñas se alinean claramente con categorías específicas: duración de la batería y rendimiento para la reseña 1, y rendimiento para la reseña 3.
# Granite Model Formatted Response:
#
# - Sentimiento: Positivo
#   - Categorías: Duración de la batería, Rendimiento general
#
# - Sentimiento: Mixto
#   - Categorías: Visibilidad de la pantalla, Experiencia de uso interior vs exterior
#
# - Sentimiento: Negativo
#   - Categorías: Velocidad del dispositivo, Estabilidad de las aplicaciones
# Granite Model Response:
#
# **Resumen de la Reunión:**
#
# 1. **Presupuesto de Marketing (Q3):** Se asignó el 40% para anuncios digitales, 30% para eventos y 30% para campañas en redes sociales. Se acordó priorizar asociaciones con influencers y el marketing por correo electrónico para aumentar la interacción directa. Un programa piloto de nuevos formatos publicitarios se lanzará el próximo mes, con una revisión de resultados a finales del Q3.
#
# 2. **Métricas de Rendimiento y ROI:** Se destacó la importancia del seguimiento del ROI y se acordó realizar ajustes basados en datos de rendimiento.
#
# 3. **Recursos para Eventos:** El equipo de eventos expresó preocupaciones sobre la asignación de recursos para ferias comerciales futuras. Como resultado, se reasignaron $10,000 adicionales para cubrir estos gastos.
#
# 4. **Conceptos Creativos:** Se revisaron nuevos conceptos para la próxima campaña. Se decidió continuar con el Concepto 8, que recibió mejores evaluaciones en grupos de enfoque. Se establecieron plazos estrictos: todos los activos de campaña deben entregarse antes del 15 de julio.
# Granite Model Refined Response:
#
# En esta reunión, el equipo asignó un presupuesto de marketing trimestral, destinando el 40% a anuncios digitales, el 30% a eventos y el 30% a campañas en redes sociales, con un énfasis en colaboraciones con influencers y marketing por correo electrónico. Se planea lanzar un programa piloto para probar nuevos anuncios digitales, con una revisión de los resultados en el tercer trimestre. El equipo también priorizará el seguimiento del ROI, ajustando estrategias según los datos de rendimiento. Además, se reasignaron $10,000 adicionales para eventos comerciales debido a preocupaciones de recursos. Se seleccionó el Concepto 8 para la próxima campaña basándose en resultados de grupos focales y se estableció un plazo de entrega para activos de campaña el 15 de julio.
# Granite Model Response for refined focus area response:
#
# **Resumen de la Reunión:**
#
# 1. **Presupuesto de Marketing (3T):**
#    - **Decisión:** 40% para anuncios digitales, 30% para eventos y 30% para campañas en redes sociales.
#    - **Acción:** Establecer asociaciones con influencers y optimizar el marketing por correo electrónico.
#    - **Próxima etapa:** Lanzamiento de un programa piloto con nuevos formatos de anuncios en agosto, con revisión de resultados a finales del 3T.
#
# 2. **Métricas de Rendimiento:**
#    - **Enfoque:** Priorizar el seguimiento del ROI y realizar ajustes según datos de rendimiento.
#
# 3. **Recursos de Eventos:**
#    - **Preocupación:** Equipo de Eventos solicitó más recursos para ferias comerciales.
#    - **Decisión:** Asignación adicional de $10,000 para cubrir estos gastos.
#
# 4. **Conceptos Creativos para la Campaña:**
#    - **Selección:** Decisión de continuar con el Concepto 8 debido a los mejores resultados en los grupos focales.
#    - **Plazos:** Todos los activos de campaña deben entregarse antes del 15 de julio.
#
# Esta reunión se centró en la alocación del presupuesto de marketing, el monitoreo del rendimiento, la asignación de recursos para eventos y la selección de conceptos creativos para la próxima campaña. Se tomaron decisiones claras y se definieron acciones específicas, con plazos claros para cada tarea. El enfoque en métricas de ROI y la flexibilidad para ajustar estrategias según los datos de rendimiento destacan el compromiso con un enfoque datos-impulsado. Además, el aumento de recursos para los eventos y la selección definitiva del Concepto 8 para la campaña muestran un progreso significativo en la planificación de la pró
# Granite Model Response for refined output format response:
#
# **Puntos clave discutidos:**
#
# - Allocation del presupuesto de marketing: 40% para anuncios digitales, 30% para eventos y 30% para campañas en redes sociales.
# - Estrategia de marketing por correo electrónico y colaboraciones con influencers para aumentar la interacción y la visibilidad de la marca.
# - Implementación de un programa piloto de nuevos formatos publicitarios a finales del tercer trimestre.
#
# **Decisiones tomadas:**
#
# - Asignación adicional de $10.000 para recursos de eventos en ferias comerciales.
# - Selección del Concepto 8 para la próxima campaña de marketing debido a su mejor rendimiento en grupos focales.
# - Priorización del seguimiento del ROI y ajuste de estrategias según los datos de rendimiento.
#
# **Acciones pendientes:**
#
# - Presentación de todos los activos de campaña para el 15 de julio.
# - Evaluación de resultados del programa piloto de formatos publicitarios a finales del tercer trimestre.
# - Monitoreo continuo del ROI y ajustes de estrategia en función de métricas de rendimiento.
#
# **Cronograma:**
#
# - Programa piloto de nuevos formatos publicitarios: lanzamiento próximo, evaluación a finales del tercer trimestre.
# - Entrega de activos de campaña: plazo el 15 de julio.
# - Revisión del ROI y ajustes estratégicos: proceso continuo con un enfoque particular a finales del trimestre.
